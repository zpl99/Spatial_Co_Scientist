# %%
import argparse
from src.tot.methods.bfs import solve
from src.tot.tasks.game24 import Game24Task

args = argparse.Namespace(backend='gpt-4', temperature=0.7, task='game24', naive_run=False, prompt_sample=None, method_generate='propose', method_evaluate='value', method_select='greedy', n_generate_sample=1, n_evaluate_sample=3, n_select_sample=5)

task = Game24Task()
ys, infos = solve(args, task, 900)
print(ys[0])
# Out:
# ()
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# File /opt/anaconda3/envs/tot/lib/python3.10/site-packages/backoff/_sync.py:105, in retry_exception.<locals>.retry(*args, **kwargs)
#     104 try:
# --> 105     ret = target(*args, **kwargs)
#     106 except exception as e:
#
# File ~/Library/CloudStorage/OneDrive-TheUniversityofTexasatAustin/博士学习/6-Job/ESRI/Spatial_Co_Scientist/tree-of-thought-llm-master/src/tot/models.py:24, in completions_with_backoff(**kwargs)
#      21 @backoff.on_exception(backoff.expo, openai.error.OpenAIError)
#      22 def completions_with_backoff(**kwargs):
#      23     # Azure API uses deployment_id instead of model
# ---> 24     return openai.ChatCompletion.create(**kwargs)
#
# File /opt/anaconda3/envs/tot/lib/python3.10/site-packages/openai/api_resources/chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      24 try:
# ---> 25     return super().create(*args, **kwargs)
#      26 except TryAgain as e:
#
# File /opt/anaconda3/envs/tot/lib/python3.10/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     138 (
#     139     deployment_id,
#     140     engine,
#    (...)
#     150     api_key, api_base, api_type, api_version, organization, **params
#     151 )
# --> 153 response, _, api_key = requestor.request(
#     154     "post",
#     155     url,
#     156     params=params,
#     157     headers=headers,
#     158     stream=stream,
#     159     request_id=request_id,
#     160     request_timeout=request_timeout,
#     161 )
#     163 if stream:
#     164     # must be an iterator
#
# File /opt/anaconda3/envs/tot/lib/python3.10/site-packages/openai/api_requestor.py:230, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     220 result = self.request_raw(
#     221     method.lower(),
#     222     url,
#    (...)
#     228     request_timeout=request_timeout,
#     229 )
# --> 230 resp, got_stream = self._interpret_response(result, stream)
#     231 return resp, got_stream, self.api_key
#
# File /opt/anaconda3/envs/tot/lib/python3.10/site-packages/openai/api_requestor.py:624, in APIRequestor._interpret_response(self, result, stream)
#     622 else:
#     623     return (
# --> 624         self._interpret_response_line(
#     625             result.content.decode("utf-8"),
#     626             result.status_code,
#     627             result.headers,
#     628             stream=False,
#     629         ),
#     630         False,
#     631     )
#
# File /opt/anaconda3/envs/tot/lib/python3.10/site-packages/openai/api_requestor.py:687, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     686 if stream_error or not 200 <= rcode < 300:
# --> 687     raise self.handle_error_response(
#     688         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     689     )
#     690 return resp
#
# InvalidRequestError: Resource not found
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 8
#       5 args = argparse.Namespace(backend='gpt-4', temperature=0.7, task='game24', naive_run=False, prompt_sample=None, method_generate='propose', method_evaluate='value', method_select='greedy', n_generate_sample=1, n_evaluate_sample=3, n_select_sample=5)
#       7 task = Game24Task()
# ----> 8 ys, infos = solve(args, task, 900)
#       9 print(ys[0])
#
# File ~/Library/CloudStorage/OneDrive-TheUniversityofTexasatAustin/博士学习/6-Job/ESRI/Spatial_Co_Scientist/tree-of-thought-llm-master/src/tot/methods/bfs.py:61, in solve(args, task, idx, to_print)
#      59     new_ys = [get_samples(task, x, y, args.n_generate_sample, prompt_sample=args.prompt_sample, stop=task.stops[step]) for y in ys]
#      60 elif args.method_generate == 'propose':
# ---> 61     new_ys = [get_proposals(task, x, y) for y in ys]
#      62 new_ys = list(itertools.chain(*new_ys))
#      63 ids = list(range(len(new_ys)))
#
# File ~/Library/CloudStorage/OneDrive-TheUniversityofTexasatAustin/博士学习/6-Job/ESRI/Spatial_Co_Scientist/tree-of-thought-llm-master/src/tot/methods/bfs.py:61, in <listcomp>(.0)
#      59     new_ys = [get_samples(task, x, y, args.n_generate_sample, prompt_sample=args.prompt_sample, stop=task.stops[step]) for y in ys]
#      60 elif args.method_generate == 'propose':
# ---> 61     new_ys = [get_proposals(task, x, y) for y in ys]
#      62 new_ys = list(itertools.chain(*new_ys))
#      63 ids = list(range(len(new_ys)))
#
# File ~/Library/CloudStorage/OneDrive-TheUniversityofTexasatAustin/博士学习/6-Job/ESRI/Spatial_Co_Scientist/tree-of-thought-llm-master/src/tot/methods/bfs.py:36, in get_proposals(task, x, y)
#      34 def get_proposals(task, x, y):
#      35     propose_prompt = task.propose_prompt_wrap(x, y)
# ---> 36     proposals = gpt(propose_prompt, n=1, stop=None)[0].split('\n')
#      37     return [y + _ + '\n' for _ in proposals]
#
# File ~/Library/CloudStorage/OneDrive-TheUniversityofTexasatAustin/博士学习/6-Job/ESRI/Spatial_Co_Scientist/tree-of-thought-llm-master/src/tot/models.py:28, in gpt(prompt, model, temperature, max_tokens, n, stop)
#      26 def gpt(prompt, model=deployment, temperature=0.7, max_tokens=1000, n=1, stop=None) -> list:
#      27     messages = [{"role": "user", "content": prompt}]
# ---> 28     return chatgpt(messages, deployment=model, temperature=temperature, max_tokens=max_tokens, n=n, stop=stop)
#
# File ~/Library/CloudStorage/OneDrive-TheUniversityofTexasatAustin/博士学习/6-Job/ESRI/Spatial_Co_Scientist/tree-of-thought-llm-master/src/tot/models.py:36, in chatgpt(messages, deployment, temperature, max_tokens, n, stop)
#      34 cnt = min(n, 20)
#      35 n -= cnt
# ---> 36 res = completions_with_backoff(
#      37     engine=deployment,     # Azure用engine=deployment name
#      38     messages=messages,
#      39     temperature=temperature,
#      40     max_tokens=max_tokens,
#      41     n=cnt,
#      42     stop=stop
#      43 )
#      44 outputs.extend([choice.message.content for choice in res.choices])
#      45 completion_tokens += res.usage.completion_tokens
#
# File /opt/anaconda3/envs/tot/lib/python3.10/site-packages/backoff/_sync.py:127, in retry_exception.<locals>.retry(*args, **kwargs)
#     122         raise e
#     124     _call_handlers(on_backoff, **details, wait=seconds,
#     125                    exception=e)
# --> 127     time.sleep(seconds)
#     128 else:
#     129     _call_handlers(on_success, **details)
#
# KeyboardInterrupt:
